# %%
while True:
    name = input('Enter your name or EXIT to close the program: ')
    if (name == 'EXIT'):
        break
    print('Hello', name)
# Out:
# Enter your name or EXIT to close the program:  Isaiah
# Hello Isaiah
# Enter your name or EXIT to close the program:  EXIT

# %%
for i in range(1, 21):
    if i % 5 == 0:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 19
