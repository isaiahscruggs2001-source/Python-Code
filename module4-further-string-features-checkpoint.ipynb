# %%
fav_band = 'Green Day'
print(fav_band[6])
# Out:
# D

# %%
print(fav_band[:6])
# Out:
# Green

# %%
text = 'please capitalize me'
text_cap = text.upper()
print(text_cap)
# Out:
# PLEASE CAPITALIZE ME

# %%
user_number = input('Please provide a number: ')
if user_number.isnumeric():
    print(f"Thank you, that's a correct number!")
else:
    print('Sorry,', user_number, 'is not a number!')
# Out:
# Please provide a number:  7
# Thank you, that's a correct number!
