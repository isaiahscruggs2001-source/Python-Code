# %%
name_original = 'Jon Snow'
name_new = name_original
name_original = 'Barry Allen'
print(name_original, name_new)
# Out:
# Barry Allen Jon Snow

# %%
list_original = [1,2,3]
list_new = list_original
list_original[0] = -5
print('Original:', list_original, '\nNew:', list_new)
# Out:
# Original: [-5, 2, 3]
# New: [-5, 2, 3]

# %%
list_original = [1,2,3]
list_new = list_original[:2]
list_original[0] = -5
print('Original:', list_original, '\nNew:', list_new)
# Out:
# Original: [-5, 2, 3]
# New: [1, 2]
