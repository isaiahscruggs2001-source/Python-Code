# %%
def get_number():
    for i in range(1,4):
        yield i

# %%
print(get_number())
# Out:
# <generator object get_number at 0x000001B36ECF1970>

# %%
generator = get_number()
print(next(generator))
print(next(generator))
print(next(generator))
# Out:
# 1
# 2
# 3

# %%
for x in get_number():
    print(x)
# Out:
# 1
# 2
# 3

# %%
numbers = list(get_number())
print(numbers)
# Out:
# [1, 2, 3]
