# %%
# John's monthly spending data (sample data for demonstration)
# In a real-world application, this data would likely be loaded from a file or database.
spendings = [1346.0, 987.50, 1734.40, 2567.0, 3271.45, 2500.0, 2130.0, 2510.30, 2987.34, 3120.50, 4069.78, 1000.0]


# Initialize counters for each spending category
low_spendings_count = 0
normal_spendings_count = 0
high_spendings_count = 0

print("--- John's Monthly Spending Analysis ---")

# Iterate through each spending amount in the list
for spending in monthly_spendings:
    # a. Check for low spendings (< 1000.0)
    if spending < 1000.0:
        low_spendings_count += 1
    # b. Check for normal spendings (between 1000.0 and 2500.0 inclusive)
    # Since the first condition handles < 1000, we only need to check the upper bound here.
    elif 1000.0 <= spending <= 2500.0:
        normal_spendings_count += 1
    # c. High spendings (> 2500.0) - this catches everything else
    else:
        high_spendings_count += 1

# Print the final results in the required format
print(f"Numbers of months with low spendings: {low_spendings_count}, normal spendings: {normal_spendings_count}, high spendings: {high_spendings_count}.")

# Optional: Print the total number of months analyzed for verification
print(f"\nTotal months analyzed: {len(monthly_spendings)}")
# Out:
# --- John's Monthly Spending Analysis ---
# Numbers of months with low spendings: 3, normal spendings: 6, high spendings: 3.
#
# Total months analyzed: 12

# %%
spendings = [1346.0, 987.50, 1734.40, 2567.0, 3271.45, 2500.0, 2130.0, 2510.30, 2987.34, 3120.50, 4069.78, 1000.0]
 
low = 0
normal = 0
high = 0
 
for month in spendings:
    if month < 1000.0:
        low += 1
    elif month <= 2500.0:
        normal += 1
    else:
        high += 1
 
print('Numbers of months with low spendings: ' + str(low) + ', normal spendings: ' + str(normal) + ', high spendings: ' + str(high) + '.')
# Out:
# Numbers of months with low spendings: 1, normal spendings: 5, high spendings: 6.
