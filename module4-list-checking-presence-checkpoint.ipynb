# %%
 for char in 'happy message':
     print(char)
# Out:
# h
# a
# p
# p
# y
#
# m
# e
# s
# s
# a
# g
# e

# %%
invited_guests = f'[Kate, Adam, Kerry, Joe, Anne, Marie]'
name = input('What is your name? ')
if name in invited_guests:
    print('Welcome!')
else:
    print('You are not invited!')
# Out:
# What is your name?  Dani
# You are not invited!

# %%
invited_guests = f'[Kate, Adam, Kerry, Joe, Anne, Marie]'
name = input('What is your name? ')
if name not in invited_guests:
    print('You are not invited!')
else:
    print('Welcome!')
# Out:
# What is your name?  Isaiah
# You are not invited!
