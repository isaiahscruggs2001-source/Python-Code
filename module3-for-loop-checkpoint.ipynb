# %%
for letter in 'hello!':
    print('Current letter:', letter)
# Out:
# Current letter: h
# Current letter: e
# Current letter: l
# Current letter: l
# Current letter: o
# Current letter: !

# %%
for counter in range (1,11,4):
    print(counter)
print('finished!')
# Out:
# 1
# 5
# 9
# finished!
