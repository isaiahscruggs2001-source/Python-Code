# %%
class Dog():
    counter = 0
    def __init__(self, name, age):
        self.__name = name
        self.age = age
        Dog.counter += 1

my_pet = Dog('Bruce', 13)
kates_pet = Dog('Foxy', 5)
adams_pet = Dog('Luna', 1)

print(my_pet.counter)
print(kates_pet.counter)
print(adams_pet.counter)
# Out:
# 3
# 3
# 3

# %%
my_pet.__dict__
# Out:
# {'_Dog__name': 'Bruce', 'age': 13}

# %%
print(Dog.counter)
# Out:
# 3

# %%
class Dog():
    __counter = 0
    def __init__(self, name, age):
        self.__name = name
        self.age = age
        Dog.__counter += 1

# %%
print(Dog._Dog__counter)
# Out:
# 0

# %%
print(Dog.__dict__)
# Out:
# {'__module__': '__main__', '__firstlineno__': 1, '_Dog__counter': 0, '__init__': <function Dog.__init__ at 0x00000171A0D55B20>, '__static_attributes__': ('__name', 'age'), '__dict__': <attribute '__dict__' of 'Dog' objects>, '__weakref__': <attribute '__weakref__' of 'Dog' objects>, '__doc__': None}

# %%
class Dog():
    counter = 0
    def __init__(self, name, age):
        self.name = name
        self.age = age
        Dog.counter += 1

my_pet = Dog('Tom', 5)

if hasattr(my_pet, 'name'):
    print('My pet is called', my_pet.name)
else:
    print('My pet has no name')

if hasattr(Dog, 'counter'):
    print('The Dog class has a counter!')
else:
    print('The Dog class does not have a counter')
# Out:
# My pet is called Tom
# The Dog class has a counter!

# %%
print(Dog.__name__)
# Out:
# Dog

# %%
my_pet = Dog('Tom', 5)

type(my_pet).__name__
# Out:
# 'Dog'

# %%
print(Dog.__module__)
# Out:
# __main__
