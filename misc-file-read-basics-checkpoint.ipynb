# %%
try:
    stream = open('animals.txt')
    # your code goes here
    stream.close()
except Exception as e:
    print('An error occured: ', e)
# Out:
# An error occured:  [Errno 2] No such file or directory: 'animals.txt'

# %%
try:
    stream = open('animalsss.txt')
    # your code goes here
    stream.close()
except Exception as e:
    print('An error occured: ', e)
# Out:
# An error occured:  [Errno 2] No such file or directory: 'animalsss.txt'

# %%
try:
    stream = open('animals.txt')
    print(stream.read(10))
    print(stream.read(10))
    stream.close()
except Exception as e:
    print('An error occured: ', e)
# Out:
# PIG is a d
# omestic an

# %%
try:
    stream = open('animals.txt')
    print(stream.read(10000))
    print(stream.read())
    stream.close()
except Exception as e:
    print('An error occured: ', e)
# Out:
# PIG is a domestic animal.
# LION is a wild animal.
# FOX is a wild animal that is sometimes kept as a pet.

# %%
try:
    stream = open('animals.txt')
    character = stream.read(1)
    while character != '':
        print(character, end= '-')
        character = stream.read(1)
    stream.close()
except Exception as e:
    print('An error occured: ', e)
# Out:
# P-I-G- -i-s- -a- -d-o-m-e-s-t-i-c- -a-n-i-m-a-l-.-
# -L-I-O-N- -i-s- -a- -w-i-l-d- -a-n-i-m-a-l-.-
# -F-O-X- -i-s- -a- -w-i-l-d- -a-n-i-m-a-l- -t-h-a-t- -i-s- -s-o-m-e-t-i-m-e-s- -k-e-p-t- -a-s- -a- -p-e-t-.- -

# %%
try:
    stream = open('animals.txt')
    counter = 0
    character = stream.read(1)
    while character != '':
        counter += 1
        print(character, end= '-')
        character = stream.read(1)
    stream.close()
    print(f"\nNumber of characters:", counter)
except Exception as e:
    print('An error occured: ', e)
# Out:
# P-I-G- -i-s- -a- -d-o-m-e-s-t-i-c- -a-n-i-m-a-l-.-
# -L-I-O-N- -i-s- -a- -w-i-l-d- -a-n-i-m-a-l-.-
# -F-O-X- -i-s- -a- -w-i-l-d- -a-n-i-m-a-l- -t-h-a-t- -i-s- -s-o-m-e-t-i-m-e-s- -k-e-p-t- -a-s- -a- -p-e-t-.- -
# Number of characters: 103

# %%
try:
    stream = open('animals.txt')
    counter = 0
    line = stream.readline()
    while line != '':
        counter += 1
        print(line, end= '-')
        line = stream.readline()
    stream.close()
    print(f"\nNumber of lines:", counter)
except Exception as e:
    print('An error occured: ', e)
# Out:
# PIG is a domestic animal.
# -LION is a wild animal.
# -FOX is a wild animal that is sometimes kept as a pet. -
# Number of lines: 3

# %%
try:
    stream = open('animals.txt')
    lines = stream.readlines()
    print('Content of the lines var:', lines)
    print('Number of the lines in the file:', len(lines))
    for line in lines:
        print(line, end='')
    stream.close()
except Exception as e:
    print('An error occured: ', e)
# Out:
# Content of the lines var: ['PIG is a domestic animal.\n', 'LION is a wild animal.\n', 'FOX is a wild animal that is sometimes kept as a pet. ']
# Number of the lines in the file: 3
# PIG is a domestic animal.
# LION is a wild animal.
# FOX is a wild animal that is sometimes kept as a pet.

# %%
try:
    stream = open('animals.txt')
    lines = stream.readlines(2)
    while len(lines) != 0:
        for line in lines:
            print(line, sep='')
        lines = stream.readlines(2)
    stream.close()
except Exception as e:
    print('An error occured: ', e)
# Out:
# PIG is a domestic animal.
#
# LION is a wild animal.
#
# FOX is a wild animal that is sometimes kept as a pet.

# %%
try:
    stream = open('animals.txt')
    for line in stream:
        print(line, end='')
except Exception as e:
    print('An error occured: ', e)
# Out:
# PIG is a domestic animal.
# LION is a wild animal.
# FOX is a wild animal that is sometimes kept as a pet.
