# %%
5 + 7
# Out:
# 12

# %%
5 - 7
# Out:
# -2

# %%
print(+12)
# Out:
# 12

# %%
print(-2)
# Out:
# -2

# %%
# ORDER OF OPERARTORS
# 1. **
# 2. */ // %
# 3. + -

# %%
2 + 3 * 2
# Out:
# 8

# %%
2 * (3+2)
# Out:
# 10

# %%
print(0.1)
# Out:
# 0.1

# %%
print(0.1 + 0.1 + 0.1)
# Out:
# 0.30000000000000004

# %%
2 ** 2 ** 3
# Out:
# 256
