# %%
import sys

# %%
import sys
import math

# %%
import sys, math

# %%
import sys

for name in dir(sys):
    print(name, end='\t')
# Out:
# __breakpointhook__	__displayhook__	__doc__	__excepthook__	__interactivehook__	__loader__	__name__	__package__	__spec__	__stderr__	__stdin__	__stdout__	__unraisablehook__	__warningregistry__	_base_executable	_baserepl	_clear_internal_caches	_clear_type_cache	_current_exceptions	_current_frames	_debugmallocstats	_enablelegacywindowsfsencoding	_framework	_get_cpu_count_config	_getframe	_getframemodulename	_git	_home	_is_gil_enabled	_is_interned	_setprofileallthreads	_settraceallthreads	_stdlib_dir	_vpath	_xoptions	activate_stack_trampoline	addaudithook	api_version	argv	audit	base_exec_prefix	base_prefix	breakpointhook	builtin_module_names	byteorder	call_tracing	copyright	deactivate_stack_trampoline	displayhook	dllhandle	dont_write_bytecode	exc_info	excepthook	exception	exec_prefix	executable	exit	flags	float_info	float_repr_style	get_asyncgen_hooks	get_coroutine_origin_tracking_depth	get_int_max_str_digits	getallocatedblocks	getdefaultencoding	getfilesystemencodeerrors	getfilesystemenco
# ...

# %%
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\IsaiahS\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import sys

sys.exit324()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 import sys
# ----> 3 sys.exit324()
#
# AttributeError: module 'sys' has no attribute 'exit324'

# %%
import sys

def exit():
    print('I wanna exit')

exit()
sys.exit()
# Out:
# I wanna exit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
from sys import exit

exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
from sys import exit

def exit():
    print('I wanna exit')

exit()
# Out:
# I wanna exit

# %%
#not recommended; too complicated 
from sys import *

# %%
import sys # you need to add sys.
from sys import *

# %%
import sys as s

s.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
from sys import exit as bye_bye

bye_bye()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
