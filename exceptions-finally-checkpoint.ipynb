# %%
def get_inverse(x):
    try:
        return 1 / x
    except ZeroDivisionError:
        return None
    finally:
        print('I am always printed!')

# %%
print(get_inverse(5))
# Out:
# I am always printed!
# 0.2

# %%
print(get_inverse(0))
# Out:
# I am always printed!
# None
