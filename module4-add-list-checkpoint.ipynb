# %%
print('hello')
# Out:
# hello

# %%
name = input('name?')
# Out:
# name? Isaiah

# %%
book_ratings = [7, 9, 5, 6, 8]
book_ratings.append(4)
print(book_ratings)
# Out:
# [7, 9, 5, 6, 8, 4]

# %%
book_ratings = [7, 9, 5, 6, 8]
book_ratings.insert(1, 10)
print(book_ratings)
# Out:
# [7, 10, 9, 5, 6, 8]
