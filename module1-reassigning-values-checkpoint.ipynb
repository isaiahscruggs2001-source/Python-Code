# %%
age = 28
print(age)
# Out:
# 28

# %%
age = 28
new_age = age + 5

# %%
print(new_age)
# Out:
# 33

# %%
age = 28
age = age + 7
print(age)
# Out:
# 35

# %%
age = 28
age += 7
print(age)
# Out:
# 35

# %%
age *= 2
age -= 5
age /= 3

# %%
text = 'hocus' + 'pocus'
print(text)
# Out:
# hocuspocus

# %%
print('hocus' * 5)
# Out:
# hocushocushocushocushocus

# %%
print('23' + '5')
# Out:
# 235
