# %%
def my_fun(x):
  try:
    return x / x
  except:
    print('ex')
 
my_fun(1)
my_fun(0)
# Out:
# ex

# %%
try:
  raise Exception(2)
except Exception as e:
  print(len(e.args))
# Out:
# 1

# %%
class MyEx(Exception):
  def __init__(self, msg):
    Exception.__init__(self, msg+msg)
    self.args = (msg,)
 
try:
  raise MyEx('wrong!')
except Exception as e:
  print(e)
# Out:
# wrong!

# %%
try:
  x = 5
except:
  print("a")
else:
  print("b")
finally:
  print("c") 
x = 5
# Out:
# b
# c

# %%
try:
  val = int(input('Provide a number: '))
  print(val/val)
except TypeError:
  print('a')
except ValueError:
  print('b')
except ZeroDivisionError:
  print('c')
except:
  print('d')
# Out:
# Provide a number:  a
# b

# %%
user_input = int(input('What is your value? '))
print(1/user_input)
# Out:
# What is your value?  0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 user_input = int(input('What is your value? '))
# ----> 2 print(1/user_input)
#
# ZeroDivisionError: division by zero

# %%
#Miscellaneous
samp = [i + 2 * i for i in range(3)]
print(samp)
# Out:
# [0, 3, 6]

# %%
val = lambda x, y: x + y ** y
print(val(3, 2))
# Out:
# 7

# %%
print(list(filter(lambda i: i % 2 != 0, [x for x in range(10)])))
# Out:
# [1, 3, 5, 7, 9]

# %%
arr = bytearray(2)
print(arr)
# Out:
# bytearray(b'\x00\x00')

# %%
lst = [2, 4, 6]
lst = list(filter(lambda a: a % 4 != 0, lst))
lst = print(lst)
# Out:
# [2, 6]

# %%
def first(x):
  def second(y):
    return x * y
  return second
 
a = first(5)
b = first(2)
 
print(a(2) + b(3))
# Out:
# 16
