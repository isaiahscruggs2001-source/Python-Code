# %%
class Dog():
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
my_pet = Dog('Bruce', 13)
my_pet.__dict__
# Out:
# {'name': 'Bruce', 'age': 13}

# %%
my_pet.color = 'Brown'
my_pet.__dict__
# Out:
# {'name': 'Bruce', 'age': 13, 'color': 'Brown'}

# %%
del my_pet.name
my_pet.__dict__
# Out:
# {'age': 13, 'color': 'Brown'}

# %%
class Dog():
    def __init__(self, name, age):
        self.__name = name
        self.age = age

# %%
my_pet = Dog('Bruce', 13)
print(my_pet.__dict__)
# Out:
# {'_Dog__name': 'Bruce', 'age': 13}

# %%
my_pet = Dog('Bruce', 13)
print(my_pet.__dict__)
print(my_pet._Dog__name)
# Out:
# {'_Dog__name': 'Bruce', 'age': 13}
# Bruce

# %%
my_pet.__breed = 'Bulldog'
print(my_pet.__dict__)
# Out:
# {'_Dog__name': 'Bruce', 'age': 13, '__breed': 'Bulldog'}
