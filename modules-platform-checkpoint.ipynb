# %%
# platform(): access to underlying platforms identifying data; tells you about your python version, the OS, and the hardware you're using
import platform

# %%
platform.platform()
# Out:
# 'Windows-10-10.0.19045-SP0'

# %%
platform.platform(True, True)
# Out:
# 'Windows-10'

# %%
platform.machine()
# Out:
# 'AMD64'

# %%
platform.processor()
# Out:
# 'Intel64 Family 6 Model 166 Stepping 0, GenuineIntel'

# %%
platform.system()
# Out:
# 'Windows'

# %%
platform.python_implementation()
# Out:
# 'CPython'

# %%
platform.python_version_tuple()
# Out:
# ('3', '13', '5')
